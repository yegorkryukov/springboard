# %% [markdown]
# # Prepare CSV for autoML

# %% [markdown]
# # Clean

# %%
def clean_and_tokenize_text(text):
    """
    Cleans `text` from punctuation and special symbols
    """    
    # need to adjust this for better cleaning
    from nltk.tokenize import word_tokenize
    from nltk.stem import WordNetLemmatizer
    from nltk.corpus import stopwords

    lower_alpha_tokens = [w for w in word_tokenize(text.lower()) if w.isalpha()]
    no_stop = [t for t in lower_alpha_tokens if t not in set(stopwords.words('english'))]
    
    wnl = WordNetLemmatizer()
    lemmatized = [wnl.lemmatize(t) for t in no_stop]
    return lemmatized

def quality_check(article):
    """
    Checks for quality of the `article` and returns False if it doesnt' pass the 
    QA check
    """
    
    # need to find ways for better QA
    if article and len(article) > 250: return True
    return False

def concat_news(ticker, period=1):
    """
    Reads all news from the `DB` for the `ticker`, 
    concats by the `period`.
    
    Input
    -----
    period: int, default 1 (day)
    
    Output
    ------
    resulting_dictionary: dict, key–day, value–all news for that day
    Counter(all_tokens)
    """
    from collections import Counter
    
    news = collection.find_one({
        'ticker' : ticker
    })['news']
    
    resulting_dictionary = {}
    
    all_tokens = []
    
    for n in news:
        try:
            date = str(pd.to_datetime(n['datetime']).date())

            tokens = clean_and_tokenize_text(n['text'])

            text = ' '.join(tokens)

            all_tokens.extend(tokens)

            if quality_check(text):
                if date in resulting_dictionary.keys():
                    resulting_dictionary[date] = resulting_dictionary[date] + text
                else:
                    resulting_dictionary[date] = text
        except Exception as e:
            print(f"Cannot process url: {n['url']}\nError: {e}")
    
    return resulting_dictionary, Counter(all_tokens)

# %% [markdown]
# # Creating the dataset for AutoML

# %%
from yahoo_fin import stock_info as si 
import pymongo as pm
import pandas as pd
from datetime import date

# create dataset for predicting pricing for a company

# set the company ticker
ticker = 'AAPL'

# set interval
start_date = '01/01/2017'
end_date = date.today()

# obtain historical stock pricing data
t_data = si.get_data(ticker, start_date=start_date, end_date=end_date)

# Start MongoDB
# !brew services start mongodb-community@4.2

# Stop MongoDB
# !brew services stop mongodb-community@4.2

# connect to DB
client = pm.MongoClient('mongodb://localhost:27017')
collection = client['news']['recommendations']

# get the dictionary with all news per period (1 day) and BOW (bag of words)
t_news, t_bow = concat_news(ticker, period=1)

# convert to pandas df
t_df = pd.DataFrame.from_dict(t_news, orient='index', columns=['text'])
t_df.index = pd.to_datetime(t_df.index)

# combine news with stock price 'adjclose'
t_combined = pd.concat([t_df, t_data.adjclose], axis=1)

# drop rows without the news
t_combined = t_combined[t_combined.text.notna()]

# fill adjclose for over the weekends and holiday
# logic is the price on monday close is the result of 
# the news over the weekend hence backfill
t_combined.adjclose = t_combined.adjclose.fillna(method='backfill')

# drop rows without the stock price
t_combined = t_combined[t_combined.adjclose.notna()]


t_combined.tail(20)
# Out:
# Cannot process url: http://www.ft.com/cms/s/9c847838-ca25-43cf-a962-0d3588d8d34d,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev
# Error: 'NoneType' object has no attribute 'date'
# Cannot process url: https://www.barrons.com/articles/the-stock-market-is-headed-for-a-huge-quarter-is-a-tech-bubble-in-the-making-51592948400?siteid=yhoof2
# Error: 'NoneType' object has no attribute 'date'
# Cannot process url: https://www.barrons.com/articles/mercedes-benz-nvidia-sign-deal-to-make-cars-more-like-iphones-51592933400?siteid=yhoof2
# Error: 'NoneType' object has no attribute 'date'
# Cannot process url: https://www.barrons.com/articles/apple-stock-tim-cook-keynote-wwdc-speech-51592929033?siteid=yhoof2
# Error: 'NoneType' object has no attribute 'date'
# Cannot process url: https://www.reuters.com/article/uk-goldman-sachs-probe-idUKKBN1XK00D
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/dow-trades-at-session-low-after-fed-statement-with-less-than-a-half-hour-left-in-regular-session-2018-05-02?mod=bnbh
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/carly-fiorina-tim-cook-is-hypocritical-about-indiana-religious-freedom-law-2015-04-03
# Error: 'datetime'
# Cannot process url: https://www.reuters.com/article/us-china-cyber-apple/apple-tells-congress-it-found-no-signs-of-hacking-attack-idUSKCN1MH0YQ
# Error: 'datetime'
# Cannot process url: http://www.reuters.com/article/2015/10/20/us-apple-court-encryption-idUSKCN0SE2NF20151020
# Error: 'datetime'
# Cannot process url: https://money.cnn.com/2018/09/26/investing/insider-selling-stocks-buybacks/index.html
# Error: 'datetime'
# Cannot process url: http://money.cnn.com/2018/04/24/investing/dow-stocks-3m-caterpillar/index.html
# Error: 'datetime'
# Cannot process url: https://www.reuters.com/article/us-usa-stocks/wall-st-falls-as-china-tariffs-revive-trade-war-fears-idUSKCN1H90XP?utm_campaign=trueAnthem%3A+Trending+Content&amp;utm_content=5ac2389904d30134c9f97a34&amp;utm_medium=trueAnthem&amp;utm_source=facebook
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/robots-american-manufacturing-51550431888
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/us-stocks-futures-in-the-red-ahead-of-mcdonalds-coca-cola-results-2015-04-22?dist=afterbell
# Error: 'datetime'
# Cannot process url: https://www.cnn.com/2018/12/04/investing/stock-market-today-dow-jones/index.html
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/dow-futures-jump-almost-100-points-as-us-stocks-look-set-for-rebound-2015-09-02?link=MW_home_latest_news
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/wall-street-set-to-rebound-after-massive-selloff-futures-rally-3-2015-08-25?dist=beforebell
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/us-stock-futures-dow-eyes-triple-digit-gain-after-china-ends-higher-2016-01-08?dist=beforebell
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/us-stock-futures-climb-dow-on-track-to-break-7-session-losing-run-2015-08-10?dist=afterbell
# Error: 'datetime'
# Cannot process url: http://www.marketwatch.com/story/us-flips-the-script-on-jobs-reshoring-finally-outpaced-offshoring-in-2014-2015-05-01
# Error: 'datetime'
# Cannot process url: http://www.reuters.com/article/us-berkshire-buffett-idUSKBN1820J4
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/dow-futures-slide-150-points-signaling-another-painful-session-2018-01-30
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/dow-futures-drop-100-points-as-doubts-over-us-china-trade-deal-emerge-2018-12-04
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/dow-futures-drop-more-than-150-points-as-trump-makes-more-trade-threats-2018-06-25
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/the-technology-that-should-finally-make-your-wallet-obsolete-2019-09-06
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/amazon-lawsuit-over-10-billion-jedi-contract-145924302.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/for-the-economy-and-stock-markets-expect-a-second-half-of-fits-and-starts-as-covid-19-lingers-51593723715?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/03/google-stays-in-the-augmented-reality-race-with-a.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/03/how-this-apple-iphone-rumor-could-boost-sales.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/google-backed-groups-criticize-apples-081119307.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/global-markets-asian-shares-hit-060743373.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/taiwans-foxconn-says-customs-clearing-033651359.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/global-markets-asian-shares-hit-030640543.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/what-a-democratic-sweep-could-mean-for-the-market-51593739012?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/global-markets-asian-stocks-set-235957747.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/google-probe-states-split-strategy-232453990.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/warren-buffetts-market-indicator-nears-230236828.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/here-are-the-best-10-tech-stocks-of-2020-so-far-51593730682?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/big-tech-ceos-testify-congress-192004023.html
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/what-could-save-the-stock-market-in-julymore-government-borrowing-and-federal-reserve-money-printing-2020-07-01?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/these-5-dividend-funds-offer-the-flexibility-to-weather-the-pandemic-51593693001?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/ceos-of-alphabet-amazon-apple-and-facebook-to-testify-before-congress-in-late-july-report-2020-07-01?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/u-tech-chief-executives-expected-220401069.html
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/dow-jones-flat-as-apple-aims-to-reduce-5g-iphone-d.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/stress-test-results-could-lead-to-dividend-cuts-sh.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/peloton-app-comes-to-roku-devices-stock-gains-2020-07-01?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-top-stocks-for-july.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/streaming-tv-services-increase-prices-160116916.html
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-stocks-ill-hold-forever.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/google-youtube-tv-raises-prices-145727962.html
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/articles/markets/082515/how-theskimm-works-and-makes-money.asp?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/microsoft-tried-to-take-on-amazon-in-videogame-streaming-it-quickly-failed-51593613532?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/investing-legend-burton-malkiel-on-day-trading-millennials-the-end-of-the-6040-portfolio-and-more-2020-06-22?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-warren-buffett-stocks-buy-and-hold-next-decade.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/amazons-brand-value-surges-32-higher-according-to.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article
# Error: 'datetime'
# Cannot process url: https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-coronavirus-stock-market-rally-tesla-surges-record-high-boeing-fedex/?src=A00220
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/these-stocks-including-tesla-and-apple-are-the-real-winners-for-the-second-quarter-of-2020-2020-06-30?siteid=yhoof2
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/column-one-hundred-years-certitude-060000863.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/major-indices-open-flat-coronavirus-135504574.html
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/megacap-tech-stocks-will-continue-leading-markets-higher?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/the-fed-s-corporate-bond-portfolio-5069989?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/invest-sapientx-ai-tech-takes-155116774.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/gary-vaynerchuk-most-advertisers-dont-know-what-facebook-should-do-about-hate-speech-175414102.html
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/articles/markets/120115/top-5-apple-shareholders.asp?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/06/30/dow-jones-clings-to-gain-as-boeing-loses-orders-ap.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/here-are-tech-companies-plans-for-increasing-diversity-amid-protests-over-racial-inequality-2020-06-25?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apple-reportedly-cuts-iphone-5g-shipments?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: http://www.ft.com/cms/s/976fb2cb-3325-478b-82b4-aed030da0041,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apple-booking-holdings-tripadvisor-tech-midday-movers?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-close-14-retail-stores-185416499.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/no-ceo-was-quicker-to-warn-about-the-financial-risks-from-covid-19-than-apples-tim-cook-51593221073?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/investing-legend-burton-malkiel-on-day-trading-millennials-the-end-of-the-6040-portfolio-and-more-2020-06-22?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/why-us-china-relations-are-worsening-on-almost-every-front-213714768.html
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/03/how-this-apple-iphone-rumor-could-boost-sales.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/chart/%5ERUT
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/coronavirus-update-us-sets-new-record-in-cases-as-more-officials-back-masks-in-public-161101651.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/apple-shuts-32-stores-covid-19-cases-florida-51593116790?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/top-strategists-on-where-to-invest-now-4843888?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/ios-14-update-changes-183623089.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-store-closing-states-coronavirus-163844235.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/quote/%5EGSPC?p=^GSPC
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/dow-futures-sink-270-points-after-best-quarter-in-three-decades-ahead-of-adp-jobs-fed-minutes-2020-07-01?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-coronavirus-stock-market-rally-tesla-surges-record-high-boeing-fedex/?src=A00220&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/microsoft-stock-record-first-half-apple-most-valuable-cloud-services-51593549326?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/hp-ceo-enrique-lores-we-are-a-purpose-driven-brand-124100115.html
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/expect-violently-flat-markets-but-be-ready-to-buy-the-dip-analyst-says-2020-06-15?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/02/apple-re-closing-77-stores-due-to-coronavirus.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/ceos-of-alphabet-amazon-apple-and-facebook-to-testify-before-congress-in-late-july-report-2020-07-01?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/amazons-brand-value-surges-32-higher-according-to.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-coronavirus-stock-market-rally-fang-stocks-facebook-netflix-tesla-deliveries/?src=A00220&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/apple-reportedly-changing-the-strategic-focus-of-a.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/dow-jones-flat-as-apple-aims-to-reduce-5g-iphone-d.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/articles/markets/082515/how-theskimm-works-and-makes-money.asp?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-hoping-foundation-game-thrones-080001051.html
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/what-to-expect-for-the-markets-next-week-4584772?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/microsoft-tried-to-take-on-amazon-in-videogame-streaming-it-quickly-failed-51593613532?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/apple-could-be-worth-2-trillion-51593162001?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/02/could-the-iphone-12-propel-apples-stock-past-500.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/what-a-democratic-sweep-could-mean-for-the-market-51593739012?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: http://www.ft.com/cms/s/2fb504a3-fbc7-40a8-8996-f7dae596c831,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/u-china-feud-quietly-gets-220000203.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-google-block-dozens-chinese-062056035.html
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/03/google-stays-in-the-augmented-reality-race-with-a.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/for-the-economy-and-stock-markets-expect-a-second-half-of-fits-and-starts-as-covid-19-lingers-51593723715?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/06/30/where-will-skyworks-solutions-be-in-10-years.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/here-are-the-best-10-tech-stocks-of-2020-so-far-51593730682?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/02/why-apples-shares-rose-147-in-june.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/stress-test-results-could-lead-to-dividend-cuts-sh.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/yahoo-finance-premium-webinars-trading-234403737.html
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apples-2020-iphones-no-earpods-usb-charger-report?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apple-to-reclose-30-more-stores-coronavirus?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/video/fed-moves-forward-plan-purchase-185711267.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/quote/%5ERUT?p=^RUT
# Error: 'datetime'
# Cannot process url: http://www.ft.com/cms/s/9446192a-aff1-4e95-93fb-a5adfbc7bbd5,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/us-stocks-wall-street-ends-203314971.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/chart/%5EDJI
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/chart/%5EGSPC
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/quote/%5EDJI?p=^DJI
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/silicon-valley-economy-remains-strong-100-days-into-coronavirus-compared-to-other-industries-2020-06-26?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/modern-mobile-app-needs-revamp-174004824.html
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/02/dow-jones-rises-on-jobs-report-apple-and-mcdonalds.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/pot-car-antitrust-cases-expose-150042949.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/apple-dazzled-with-wwdc-event-why-virtual-trade-shows-could-be-the-future-51593210508?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-stock-market-rally-coronavirus-cases-rise-what-to-do/?src=A00220&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/these-stocks-including-tesla-and-apple-are-the-real-winners-for-the-second-quarter-of-2020-2020-06-30?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/cloud-software-company-jamf-files-for-ipo-2020-06-30?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/apple-re-closes-30-more-stores-including-15-in-southern-california-51593640322?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/these-5-dividend-funds-offer-the-flexibility-to-weather-the-pandemic-51593693001?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/02/got-2000-buy-these-2-best-in-breed-stocks-im-never.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-top-stocks-for-july.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://realmoney.thestreet.com/investing/technology/microsoft-s-store-closings-drive-home-the-uniqueness-of-apple-s-retail-success-15359640?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/nytimes-ends-partnership-with-apple-news?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/apple-wants-more-engaging-arcade-games.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.investopedia.com/amazon-s-brand-value-crosses-usd400-billion-amid-lockdowns-5070100?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/microsoft-permanently-shuts-retail-stores?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-warren-buffett-stocks-buy-and-hold-next-decade.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/06/30/apple-news-loses-new-york-times-in-major-blow-to-t.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apple-aapl-suppliers-5g-iphone-production-delays?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/41-of-businesses-listed-on-yelp-have-closed-for-good-during-the-pandemic-2020-06-25?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/apple-patents-reveal-ambitions-in-augmented-reality-and-more-2020-06-25?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/quote/%5EIXIC?p=^IXIC
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/peloton-app-comes-to-roku-devices-stock-gains-2020-07-01?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-launches-online-portal-apple-171133735.html
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/next-generation-apple-iphones-seen-shipping-without-power-adapter-or-earpods-51593442895?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/these-5-giant-stocks-are-driving-the-us-market-now-but-bigger-is-not-always-better-2020-06-26?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.barrons.com/articles/stocks-gains-grow-as-boeing-news-housing-sales-boost-spirits-51593449249?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/chart/%5EIXIC
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/fleetsmith-customers-unhappy-loss-third-185023088.html
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/ios-14-lets-deaf-users-194443936.html
# Error: 'datetime'
# Cannot process url: https://www.marketwatch.com/story/apple-to-shutter-30-more-retail-stores-bringing-total-to-77-in-us-2020-07-01?siteid=yhoof2&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://finance.yahoo.com/news/apple-close-more-stores-seven-023624067.html
# Error: 'datetime'
# Cannot process url: https://www.thestreet.com/investing/apple-facebook-amazon-and-google-ceos-to-testify-congress-report?puc=yahoo&cm_ven=YAHOO&yptr=yahoo
# Error: 'datetime'
# Cannot process url: https://www.fool.com/investing/2020/07/01/5-stocks-ill-hold-forever.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article&yptr=yahoo
# Error: 'datetime'
#                                                          text    adjclose
# 2020-06-13  dow jones industrial average continued rally s...  342.989990
# 2020-06-14  warren buffett trade portfolio put protect dow...  342.989990
# 2020-06-15  secret retail investor stepping participation ...  342.989990
# 2020-06-16  douglas busvine berlin reuters germany sought ...  352.079987
# 2020-06-17  earlier week apple nasdaq aapl released result...  351.589996
# 2020-06-18  printed google logo placed apple macbook illus...  351.730011
# 2020-06-19  two main headline berkshire hathaway nyse nyse...  349.720001
# 2020-06-20  dow jones future wo begin trading sunday eveni...  358.869995
# 2020-06-21  bloomberg opinion rhetoric repeated frequently...  358.869995
# 2020-06-22  share microsoft nike trading higher monday aft...  358.869995
# 2020-06-23  perhaps better way start new week fresh closin...  366.529999
# 2020-06-24  text size global equity pressure another incre...  360.059998
# 2020-06-25  dow jones future tilted lower fair value thurs...  364.839996
# 2020-06-26  text size spotify technology made bold push po...  353.630005
# 2020-06-27  way microsoft msft plan shutter physical retai...  361.779999
# 2020-06-28  dow jones future focus sunday evening along p ...  361.779999
# 2020-06-29  new york time said want direct relationship su...  361.779999
# 2020-06-30  number iphones shipped year might half previou...  364.799988
# 2020-07-01  washington july reuters twenty advocacy group ...  364.109985
# 2020-07-02  gained million job june eliminating chunk job ...  364.109985

# %%
t_combined.to_csv(f'to_predict/{ticker}.csv', index_label='date')
